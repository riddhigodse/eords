# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhigodse/eords/blob/main/practical2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("/content/Student_Performance - Sheet1.csv")

# %%
df
# Out:
#     Rollno  gender  math_score  reading_score  writingscore  placementscore  \
# 0        1    Male         2.0             32          44.0            50.0
# 1        2    Male        42.0              7           9.0            50.0
# 2        3  Female         6.0             35          31.0            22.0
# 3        4    Male        22.0             21          47.0            47.0
# 4        5  Female        10.0             41          25.0            33.0
# 5        6    Male        42.0             28          21.0            38.0
# 6        7    Male        45.0             10          31.0            19.0
# 7        8    Male         7.0              2          48.0            15.0
# 8        9  Female         NaN              4          26.0            36.0
# 9       10    Male        13.0             17          39.0             4.0
# 10      11    Male        18.0              5           6.0             1.0
# ...

# %%
df.isnull()
# Out:
#     Rollno  gender  math_score  reading_score  writingscore  placementscore  \
# 0    False   False       False          False         False           False
# 1    False   False       False          False         False           False
# 2    False   False       False          False         False           False
# 3    False   False       False          False         False           False
# 4    False   False       False          False         False           False
# 5    False   False       False          False         False           False
# 6    False   False       False          False         False           False
# 7    False   False       False          False         False           False
# 8    False   False        True          False         False           False
# 9    False   False       False          False         False           False
# 10   False   False       False          False         False           False
# ...

# %%
series=pd.isnull(df["math_score"])

# %%
df[series]
# Out:
#     Rollno  gender  math_score  reading_score  writingscore  placementscore  \
# 8        9  Female         NaN              4          26.0            36.0
# 51      52  Female         NaN              9          26.0             8.0
#
#     placementoffercount
# 8                     1 NaN
# 51                    3 NaN

# %%
m_v=df['math_score'].mean()

# %%
df['math_score'].fillna(value=m_v,inplace=True)
# Out:
# /tmp/ipython-input-844104229.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['math_score'].fillna(value=m_v,inplace=True)

# %%
df.replace(to_replace = np.nan, value = -99)
# Out:
#     Rollno  gender  math_score  reading_score  writingscore  placementscore  \
# 0        1    Male    2.000000             32          44.0            50.0
# 1        2    Male   42.000000              7           9.0            50.0
# 2        3  Female    6.000000             35          31.0            22.0
# 3        4    Male   22.000000             21          47.0            47.0
# 4        5  Female   10.000000             41          25.0            33.0
# 5        6    Male   42.000000             28          21.0            38.0
# 6        7    Male   45.000000             10          31.0            19.0
# 7        8    Male    7.000000              2          48.0            15.0
# 8        9  Female   23.384615              4          26.0            36.0
# 9       10    Male   13.000000             17          39.0             4.0
# 10      11    Male   18.000000              5           6.0             1.0
# ...

# %%
df.isnull().sum()
# Out:
# Rollno                  0
# gender                  0
# math_score              0
# reading_score           0
# writingscore            1
# placementscore          2
# placementoffercount     0
#                        54
# dtype: int64

# %%
m_v=df['writingscore'].mean()

# %%
df['writingscore'].fillna(value=m_v, inplace=True)
# Out:
# /tmp/ipython-input-2704085795.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['writingscore'].fillna(value=m_v, inplace=True)

# %%
df
# Out:
#     Rollno  gender  math_score  reading_score  writingscore  placementscore  \
# 0        1    Male    2.000000             32     44.000000            50.0
# 1        2    Male   42.000000              7      9.000000            50.0
# 2        3  Female    6.000000             35     31.000000            22.0
# 3        4    Male   22.000000             21     47.000000            47.0
# 4        5  Female   10.000000             41     25.000000            33.0
# 5        6    Male   42.000000             28     21.000000            38.0
# 6        7    Male   45.000000             10     31.000000            19.0
# 7        8    Male    7.000000              2     48.000000            15.0
# 8        9  Female   23.384615              4     26.000000            36.0
# 9       10    Male   13.000000             17     39.000000             4.0
# 10      11    Male   18.000000              5      6.000000             1.0
# ...

# %%
m_v=df['placementscore'].mean()

# %%
df['placementscore'].fillna(value=m_v, inplace=True)
# Out:
# /tmp/ipython-input-2665357397.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['placementscore'].fillna(value=m_v, inplace=True)

# %%
df
# Out:
#     Rollno  gender  math_score  reading_score  writingscore  placementscore  \
# 0        1    Male    2.000000             32     44.000000            50.0
# 1        2    Male   42.000000              7      9.000000            50.0
# 2        3  Female    6.000000             35     31.000000            22.0
# 3        4    Male   22.000000             21     47.000000            47.0
# 4        5  Female   10.000000             41     25.000000            33.0
# 5        6    Male   42.000000             28     21.000000            38.0
# 6        7    Male   45.000000             10     31.000000            19.0
# 7        8    Male    7.000000              2     48.000000            15.0
# 8        9  Female   23.384615              4     26.000000            36.0
# 9       10    Male   13.000000             17     39.000000             4.0
# 10      11    Male   18.000000              5      6.000000             1.0
# ...

# %%
df.isnull().sum()
# Out:
# Rollno                  0
# gender                  0
# math_score              0
# reading_score           0
# writingscore            0
# placementscore          0
# placementoffercount     0
#                        54
# dtype: int64

# %%
col=['math_score','reading_score','writingscore','placementscore','placementoffercount']

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math_score']>90))
# Out:
# (array([], dtype=int64),)

# %%
print(np.where(df['reading_score']<25))
# Out:
# (array([ 1,  3,  6,  7,  8,  9, 10, 11, 16, 17, 25, 28, 29, 30, 33, 34, 35,
#        36, 37, 38, 39, 40, 46, 47, 49, 51]),)

# %%
print(np.where(df['writingscore']<30))
# Out:
# (array([ 1,  4,  5,  8, 10, 11, 13, 17, 21, 22, 23, 24, 26, 28, 29, 32, 33,
#        37, 38, 40, 41, 42, 45, 46, 47, 50, 51]),)

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['placementscore'], df['placementoffercount'])

# %%
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['placementscore'], df['placementoffercount'])
ax.set_xlabel('(Proportion non-retail businessacres)/(town)')
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(0, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['placementscore']<50) & (df['placementoffercount']>1)))
# Out:
# (array([ 2,  3,  5,  6, 10, 11, 12, 13, 16, 18, 19, 20, 22, 23, 24, 26, 28,
#        29, 30, 31, 33, 36, 37, 38, 40, 41, 42, 44, 45, 48, 49, 50, 51, 52]),)

# %%
print(np.where((df['placementscore']>85) & (df['placementoffercount']<3)))
# Out:
# (array([], dtype=int64),)

# %%
import numpy as np

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math_score']))

# %%
print(z)
# Out:
# [1.50750001 1.31228418 1.22552159 0.09760791 0.94354317 1.31228418
#  1.523768   1.15502699 0.         0.73205936 0.37958633 1.523768
#  0.80255396 0.02711331 1.50750001 0.1138759  0.39585432 1.24178958
#  1.38277879 0.87304857 0.32535971 1.31228418 1.57799462 1.08453238
#  0.18437051 1.17129497 0.16810252 0.67783274 1.38277879 1.2960162
#  1.50750001 0.09760791 1.50750001 0.95981116 0.95981116 1.22552159
#  0.45008094 1.66475721 0.81882195 0.46634892 0.94354317 0.25486511
#  1.01403778 0.73205936 1.523768   1.17129497 0.18437051 0.32535971
#  1.22552159 0.73205936 0.45008094 0.         0.60733813 0.46634892]

# %%
threshold = 0.20

# %%
sample_outliers = np.where(z <threshold)

# %%
sample_outliers
# Out:
# (array([ 3,  8, 13, 15, 24, 26, 31, 46, 51]),)

# %%
sorted_rscore= sorted(df['reading_score'])

# %%
sorted_rscore
# Out:
# [2,
#  3,
#  3,
#  4,
#  5,
#  5,
#  5,
#  7,
#  8,
#  9,
#  10,
#  12,
#  14,
#  14,
#  15,
#  16,
#  17,
#  17,
#  17,
#  18,
#  18,
#  20,
#  20,
#  21,
#  21,
#  22,
#  25,
#  25,
#  28,
#  28,
#  28,
#  29,
#  30,
#  30,
#  31,
#  32,
#  34,
#  34,
#  35,
#  36,
#  36,
#  37,
#  38,
#  39,
#  41,
#  42,
#  42,
#  43,
#  43,
#  45,
#  45,
#  45,
#  46,
#  46]

# %%
q1 = np.percentile(sorted_rscore, 25)

# %%
q3 = np.percentile(sorted_rscore, 75)

# %%
print(q1,q3)
# Out:
# 14.25 36.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)

# %%
upr_bound = q3+(1.5*IQR)

# %%
print(lwr_bound, upr_bound)
# Out:
# -18.375 68.625

# %%
r_outliers = []

# %%
r_outliers = []
for i in sorted_rscore:
  if (i<lwr_bound or i>upr_bound):
    r_outliers.append(i)
    print(r_outliers)

# %%
new_df=df
for i in sample_outliers:
 new_df.drop(i,inplace=True)
new_df
# Out:
#     Rollno  gender  math_score  reading_score  writingscore  placementscore  \
# 0        1    Male         2.0             32     44.000000            50.0
# 1        2    Male        42.0              7      9.000000            50.0
# 2        3  Female         6.0             35     31.000000            22.0
# 4        5  Female        10.0             41     25.000000            33.0
# 5        6    Male        42.0             28     21.000000            38.0
# 6        7    Male        45.0             10     31.000000            19.0
# 7        8    Male         7.0              2     48.000000            15.0
# 9       10    Male        13.0             17     39.000000             4.0
# 10      11    Male        18.0              5      6.000000             1.0
# 11      12    Male        45.0             14     27.773585            47.0
# 12      13  Female        12.0             28     36.000000             2.0
# ...
